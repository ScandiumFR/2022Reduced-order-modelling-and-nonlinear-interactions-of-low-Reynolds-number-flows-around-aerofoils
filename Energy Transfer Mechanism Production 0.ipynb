# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd

# %%
Re = 102500
n_modes = 10

mat = scipy.io.loadmat('D:\Documents\Year 3\FEEG3003 - IP\Airfoil Data\A0PIVuv.mat')
data = list(mat.items())

u = data[7]
u_mean = data[9]
v = data[8]
v_mean = data[10]
x = data[11]
y = data[12]
ts = data[3][1][0][0] # time step between snapshots
print(np.shape(u), u[0], np.shape(u_mean), u_mean[0], np.shape(v), v[0], np.shape(v_mean), v_mean[0])

samples = len(u[1])             # number of snapshots in input data
h = len(u[1][1][1])             # height of matrix = y
l = len(u[1][1])                # length of matrix = x
h_trunc = 35                    # y truncation for input data
l_trunc = 130-15                 # x truncation for input data
t_trunc = samples                 # number of time snapshots for SVD

print(samples, h, l)
# Out:
# (2,) u (2,) u_mean (2,) v (2,) v_mean
# 6998 66 186
# D:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:1970: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape

# %%
with open("dmd_0_F.csv", mode='r') as csvfile:
    data = csv.reader(csvfile)
    dmd = list(data)
with open("dmd_F_0_freqs.csv", mode='r') as csvfile:
    data = csv.reader(csvfile)
    freqs = list(data)
    
len_d = int(len(dmd)/2) #number of modes (dmd, pod in that order) from data
print(len_d)
Z = []

for j in range(0,int(len_d)):
    #manipulating modes so datasets are spatially aligned
    # FOR DMD, USE vvvvv
    #d_temp = np.reshape(dmd[len(dmd)-2-j*2],(h_trunc*2,l_trunc))
    d_temp = np.reshape(dmd[j*2],(h_trunc*2,l_trunc))
    
    Z.append(d_temp.astype(float))
    
plt.set_cmap("bwr")
fig, ax = plt.subplots()
ax.set_title('Snapshot of DMD mode - verify truncation')
cs = ax.contourf(Z[0])
fig.colorbar(cs, ax=ax)
plt.plot()
fig.canvas.draw()
# Out:
# 6

# %%
xs = []
for i in range(0, l_trunc):
    xs.append(x[1][i][1])
print(len(xs))
ys = y[1][1][0:(h_trunc)]
print(len(ys))

X_avg = np.rot90(u_mean[1][0],3)
X_avg = np.delete(X_avg, np.s_[h_trunc::], 0) # from top left, slice row 0:h. Parameter of 0 in np.delete defines rows
X_avg = np.delete(X_avg, np.s_[0:l-l_trunc], 1) # from top left, slice column 0:l. Parameter of 1 in np.delete defines columns
#Clone upper surface of A0 foil data to airfoil shadow (laser)
#filling in the missing data. Must be symmetrical for U
#For V, negate points (anti-symmetric)
y_clone = 12
x_clone = 14
X_foil_upper = np.delete(X_avg, np.s_[0:(h_trunc-y_clone-12):], 0)
X_foil_upper = np.delete(X_foil_upper, np.s_[y_clone::], 0)
X_foil_upper = np.delete(X_foil_upper, np.s_[x_clone::], 1)
X_foil_upper = np.flipud(X_foil_upper)
X_avg[0:y_clone, 0:x_clone] = X_foil_upper
fig, ax = plt.subplots()
levels = np.linspace(-1.2, 1.2, 10)
cs = ax.contourf(X_foil_upper, levels=levels)
ax.set_title('X_foil_upper')
fig.colorbar(cs, ax=ax)
plt.plot()
fig.canvas.draw()

Y_avg = np.rot90(v_mean[1][0],3)
Y_avg = np.delete(Y_avg, np.s_[h_trunc::], 0) # from top left, slice row 0:h. Parameter of 0 in np.delete defines rows
Y_avg = np.delete(Y_avg, np.s_[0:l-l_trunc], 1) # from top left, slice column 0:l. Parameter of 1 in np.delete defines columns
y_clone = 12
x_clone = 14
Y_foil_upper = np.delete(Y_avg, np.s_[0:(h_trunc-y_clone-12):], 0)
Y_foil_upper = np.delete(Y_foil_upper, np.s_[y_clone::], 0)
Y_foil_upper = np.delete(Y_foil_upper, np.s_[x_clone::], 1)
Y_foil_upper = np.flipud(Y_foil_upper)
Y_avg[0:y_clone, 0:x_clone] = -Y_foil_upper

fig, ax = plt.subplots()
levels = np.linspace(-1.2, 1.2, 10)
cs = ax.contourf(X_avg, levels=levels)
ax.set_title('U_avg')
fig.colorbar(cs, ax=ax)
plt.plot()
fig.canvas.draw()

fig, ax = plt.subplots()
levels = np.linspace(-0.2, 0.2, 10)
cs = ax.contourf(Y_avg, levels=levels)
ax.set_title('V_avg')
fig.colorbar(cs, ax=ax)
plt.plot()
fig.canvas.draw()
# Out:
# 115
# 35

# %%
dU1x1 = []
dU1x2 = []
dU2x1 = []
dU2x2 = []

[a,b] = np.gradient(X_avg.astype(float))
dU1x2.append(a)
dU1x1.append(b)
print(np.shape(dU1x2), np.shape(dU1x1))


[c,d] = np.gradient(Y_avg.astype(float))
dU2x2.append(c)
dU2x1.append(d)
print(np.shape(dU2x2), np.shape(dU2x1))

fig, ax = plt.subplots()
cs = ax.contourf(a)
ax.set_title('a')
fig.colorbar(cs, ax=ax)
plt.plot()
fig.canvas.draw()
fig, ax = plt.subplots()
cs = ax.contourf(b)
ax.set_title('b')
fig.colorbar(cs, ax=ax)
plt.plot()
fig.canvas.draw()
fig, ax = plt.subplots()
cs = ax.contourf(c)
ax.set_title('c')
fig.colorbar(cs, ax=ax)
plt.plot()
fig.canvas.draw()
fig, ax = plt.subplots()
cs = ax.contourf(d)
ax.set_title('d')
fig.colorbar(cs, ax=ax)
plt.plot()
fig.canvas.draw()
# Out:
# (1, 35, 115) (1, 35, 115)
# (1, 35, 115) (1, 35, 115)

# %%
n = 0
print(np.shape(dU2x1[n]),np.shape(np.transpose(np.matrix(dU2x1[n]).getH())))
# Out:
# (35, 115) (35, 115)

# %%
print(int(freqs[0][0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 print(int(freqs[0][0]))
#
# ValueError: invalid literal for int() with base 10: '1.234200000000000053e+01'

# %%
#print(np.shape(dU1x1), np.shape(u1), np.shape(u2))
Production = [] #Production for each mode
Production_max = []
Prod_total = np.zeros([h_trunc, l_trunc])
real = []
imag = []

for i in range(0, int(len_d/2)):
    real.append(np.vsplit(Z[i], 2)) #real V, U components
    imag.append(np.vsplit(Z[int(len_d/2)+i], 2)) #imaginary V, U components
    DMD_pos_conj = np.vectorize(complex)(real[i][0], imag[i][0]) # X, u1
    DMD_neg_conj = np.vectorize(complex)(real[i][1], imag[i][1]) # Y, u2
    
    Production.append(
        -np.multiply((np.multiply(np.transpose(np.matrix(DMD_pos_conj).getH()), DMD_pos_conj) + np.multiply(DMD_pos_conj, np.transpose(np.matrix(DMD_pos_conj).getH()))),dU1x1[0])
        -np.multiply((np.multiply(np.transpose(np.matrix(DMD_pos_conj).getH()), DMD_pos_conj) + np.multiply(DMD_pos_conj, np.transpose(np.matrix(DMD_neg_conj).getH()))),dU1x2[0])
        -np.multiply((np.multiply(np.transpose(np.matrix(DMD_neg_conj).getH()), DMD_pos_conj) + np.multiply(DMD_neg_conj, np.transpose(np.matrix(DMD_pos_conj).getH()))),dU2x1[0])
        -np.multiply((np.multiply(np.transpose(np.matrix(DMD_neg_conj).getH()), DMD_neg_conj) + np.multiply(DMD_neg_conj, np.transpose(np.matrix(DMD_neg_conj).getH()))),dU2x2[0])
                      )
    
    Production_max.append(max(Production[i].max(),-Production[i].min()))
    
fig, axes = plt.subplots(len(freqs), 1, figsize = (10,8))
n = 0
for ax in axes.flat:
    levels = np.linspace(-Production_max[n], Production_max[n], 20) # Scale plot levels
    cs = ax.contourf(Production[n], levels = levels)
    ax.set_title('Production mode ' + str(n) + ', ' + str(round(float(freqs[n][0]),1)) + 'Hz')
    fig.colorbar(cs, ax=ax)
    n = n+1
    
fig.subplots_adjust(hspace = 0.5)
fig.subplots_adjust(right=0.8)

plt.plot()
# Out:
# []

# %%
Production_sum = []
for i in Production:
    Production_sum.append(i.sum().real)
print(Production_sum)

ind = []
for i in range(0,len(freqs)):
    ind.append(str(round(float(freqs[i][0]),1)))

x=range(len(freqs))

plt.figure()
plt.ylabel('Frequency')
plt.title('Energy Production at the first three harmonic frequencies')
plt.barh(ind,Production_sum,color='r')
plt.gca().invert_yaxis()

np.savetxt('Production Energy 0deg.csv', Production_sum, delimiter = ',')

# %% [markdown]
# For the loop above:
# #only works if DMD amplitudes are correct, ignore for now
#     Prod_total = Prod_total + (
#         -np.multiply((np.multiply(np.transpose(np.matrix(DMD_pos_conj).getH()), DMD_pos_conj) + np.multiply(DMD_pos_conj, np.transpose(np.matrix(DMD_pos_conj).getH()))),dU1x1[0])
#         -np.multiply((np.multiply(np.transpose(np.matrix(DMD_pos_conj).getH()), DMD_neg_conj) + np.multiply(DMD_pos_conj, np.transpose(np.matrix(DMD_neg_conj).getH()))),dU1x2[0])
#         -np.multiply((np.multiply(np.transpose(np.matrix(DMD_neg_conj).getH()), DMD_pos_conj) + np.multiply(DMD_neg_conj, np.transpose(np.matrix(DMD_pos_conj).getH()))),dU1x2[0])
#         -np.multiply((np.multiply(np.transpose(np.matrix(DMD_neg_conj).getH()), DMD_neg_conj) + np.multiply(DMD_neg_conj, np.transpose(np.matrix(DMD_neg_conj).getH()))),dU1x2[0])
#                       )
#
# fig, ax = plt.subplots()
# cs = ax.contourf(Prod_total)
# ax.set_title('Production sum over dataset')
# fig.colorbar(cs, ax=ax)
# plt.plot()
# fig.canvas.draw()

# %%
Prod_total = np.zeros([h_trunc, l_trunc])
print(np.shape(Prod_total), np.shape(Production[0]))
for i in Production:
    Prod_total = np.add(Prod_total, Production[i])
